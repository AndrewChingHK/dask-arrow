# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# %pwd
# Out:
# '/kaggle/working'

# %%
# !pip install dask
# !pip install "dask[distributed]"
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 18.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.3/43.3 kB 1.4 MB/s eta 0:00:00
# ...

# %%
import dask.dataframe as dd
from dask.distributed import Client

# %%
client = Client()
client
# Out:
# <Client: 'tcp://127.0.0.1:42703' processes=4 threads=4, memory=30.00 GiB>

# %%
ddf = dd.read_parquet(
    "s3://dask-data/nyc-taxi/nyc-2015.parquet/part.*.parquet",
    columns=["passenger_count", "tip_amount"],
    storage_options={"anon": True},
)

# %%
ddf.head(10)
# Out:
#    passenger_count  tip_amount
# 0                5         0.0
# 1                3         0.0
# 2                1         0.0
# 3                1         0.0
# 4                2         0.0
# 5                1         1.9
# 6                3         0.0
# 7                2         2.0
# 8                2         0.0
# 9                3         0.0

# %%
result = ddf.groupby("passenger_count").tip_amount.mean().compute()
result
# Out:
# passenger_count
# 0    1.590343
# 1    1.752130
# 2    1.705595
# 3    1.579748
# 4    1.459269
# 5    1.728534
# 6    1.680769
# 7    3.863473
# 8    5.060718
# 9    5.075917
# Name: tip_amount, dtype: float64

# %%
# !conda install -c conda-forge ipycytoscape python-graphviz matplotlib zarr xarray pooch pyarrow s3fs scipy dask distributed dask-labextension -y
# Out:
# Retrieving notices: ...working... done
# Channels:
#  - conda-forge
#  - rapidsai
#  - nvidia
#  - nodefaults
#  - defaults
# Platform: linux-64
# done
# done
#
# ## Package Plan ##
#
#   environment location: /opt/conda
#
#   added / updated specs:
#     - dask
#     - dask-labextension
#     - distributed
#     - ipycytoscape
#     - matplotlib
#     - pooch
#     - pyarrow
#     - python-graphviz
#     - s3fs
#     - scipy
#     - xarray
#     - zarr
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     aiobotocore-2.15.1         |     pyhd8ed1ab_0          65 KB  conda-forge
#     aioitertools-0.12.0        |     pyhd8ed1ab_0          24 KB  conda-forge
#     alsa-lib-1.2.12            |       h4ab18f5_0         543 KB  conda-forge
#     arrow-cpp-11.0.0           |   ha770c72_9_cpu          30 KB  conda-forge
# ...
